# %%
# !pip install -U pylibjpeg pylibjpeg-openjpeg pylibjpeg-libjpeg pydicom python-gdcm

# %%
# import pydicom
# from PIL import Image
# from tqdm import tqdm
# import matplotlib.pyplot as plt
# from multiprocessing import Pool,cpu_count

# def process_dcm(path:str):
    
#     # Open the DICOM file
#     ds = pydicom.dcmread(path)
    
#     # Get the image data
#     image = ds.pixel_array

#     # Convert the image data to a PIL image
#     pil_image = Image.fromarray(image) 
    
#     # plt.imshow(pil_image,cmap="gray")
#     # print(image.shape,path)
    
#     # patient_id = path.split("/")[-2]
#     # image_id = path.split("/")[-1].split(".")[0]
    
#     # Resize the image
#     resized_image = pil_image.resize((256, 256))

#     # Save the image to a new file
#     resized_image.save(f'train/{patient_id}_{image_id}.png')
# #



# with Pool(cpu_count()) as p:
#         p.map(process_dcm, tqdm(train_images))

# %%
# %pwd
import os

# %%
# os.chdir("../")

# %%
# %pwd
# Out:
# '/home/ayush/Ayush/hackathon/DataThon/breast_cancer/experiments/data/Suspicious_cases'

# %%
# os.chdir("experiments/data/Suspicious_cases/1")

# %%
# %pwd
# Out:
# '/home/ayush/Ayush/hackathon/DataThon/breast_cancer/experiments/data/Suspicious_cases/1'

# %%
# %ls
# Out:
# CC_prior.dcm     CC_recent.dcm     MLO_prior.dcm     MLO_recent.dcm
# CC_prior_GT.jpg  CC_recent_GT.jpg  MLO_prior_GT.jpg  MLO_recent_GT.jpg

# %%
from matplotlib import pyplot as plt
im = Image.open("5/CC_prior_GT.jpg")

# %%
plt.imshow(image)
# plt.show()

# %%
width, height = im.size 
 
# Setting the points for cropped image 
left = 650
top = height / 10
right = 1350
bottom = 3* height /3.7
 
# Cropped image of above dimension 
# (It will not change original image) 
im1 = im.crop((left, top, right, bottom))
newsize = (200, 200)
im1 = im1.resize(newsize)
# Shows the image in image viewer 
plt.imshow(im1,cmap='gray')
